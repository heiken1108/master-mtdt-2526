# %%
# %load_ext autoreload
# %autoreload 2

from utils import SKNN

# %%
sknn = SKNN.SequenceKNeighborsClassifier(threshold_value=0.01)
import numpy as np
import matplotlib.pyplot as plt

# Example values from your function
w, r = sknn._exponential_decay(16, 24)

# Append r to the end of w
w = np.append(w, r)

# Plot as a bar chart
plt.bar(x=np.arange(len(w)), height=w)
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Exponential Decay Weights with Residual")
plt.show()
